# %% [markdown]
# # Download a kaggle dataset to drive

# %% [markdown]
# ## By- Pravar Kochar

# %% [markdown]
# ### Mount drive to save the dataset.

# %%
# Mount your Google Drive.
from google.colab import drive
drive.mount("/content/drive")
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-1-35d9e37eb7fc> in <cell line: 3>()
#       1 # Mount your Google Drive.
#       2 from google.colab import drive
# ----> 3 drive.mount("/content/drive")
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#     101 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#     102   """Mount your Google Drive at the specified mountpoint path."""
# --> 103   return _mount(
#     104       mountpoint,
#     105       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     130   )
#     131   if ephemeral:
# --> 132     _message.blocking_request(
# ...

# %% [markdown]
# ## Install Kaggle and configure.

# %%
# !pip install kaggle

# %%
# !mkdir ~/.kaggle

# %%
kaggle_creds_path = "/content/drive/MyDrive/kaggle.json"
# !cp $kaggle_creds_path ~/.kaggle/
# !chmod 600 /root/.kaggle/kaggle.json

# %% [markdown]
# ## Download the Kaggle dataset

# %%
# !kaggle datasets download -d nguyngiabol/colorful-fashion-dataset-for-object-detection
# Out:
# ...
# 100% 104M/104M [00:04<00:00, 32.1MB/s]
# 100% 104M/104M [00:04<00:00, 26.2MB/s]

# %% [markdown]
# ### Unzip and re-organize the folder.

# %%
# !unzip -q /content/colorful-fashion-dataset-for-object-detection.zip -d /content
# !mv /content/colorful_fashion_dataset_for_object_detection /content/kaggle_ds

# %%
# Make the dir for the data.
# !mkdir /content/drive/MyDrive/kaggle_data
# !mkdir /content/drive/MyDrive/kaggle_data/dt

# %% [markdown]
# #### Select the data usefull for YOLO.

# %%
# !mv /content/kaggle_ds/Annotations_txt/classes.txt /content/drive/MyDrive/kaggle_data
# !mv /content/kaggle_ds/Annotations_txt/* /content/drive/MyDrive/kaggle_data/dt
# !mv /content/kaggle_ds/JPEGImages/* /content/drive/MyDrive/kaggle_data/dt

# %% [markdown]
# #### Use split-folders to split in 8:1:1 ratio.

# %%
# To split data in train and test.
# !pip install split-folders

# %%
# Split data.
# !splitfolders --output /content/drive/MyDrive/kaggle_data_split --move --group_prefix 2 --ratio .8 .1 .1 -- /content/drive/MyDrive/kaggle_data
#!splitfolders --output /content/drive/MyDrive/kaggle_data_split --group_prefix 2 --ratio .8 .1 .1 -- /content/drive/MyDrive/kaggle_data

# !mv /content/drive/MyDrive/kaggle_data/classes.txt /content/drive/MyDrive/kaggle_data_split
# Out:
# Copying files: 2682 files [00:59, 44.97 files/s]

# %%
# !rm -r /content/drive/MyDrive/kaggle_data

# %% [markdown]
# ##### Minor test to verify the files.

# %%
# !echo "test"
# !echo 'All files: ' | ls -l /content/drive/MyDrive/kaggle_data_split/test/dt/*.* | grep -v ^l | wc -l
# !echo 'JPG files: ' | ls -l /content/drive/MyDrive/kaggle_data_split/test/dt/*.jpg | grep -v ^l | wc -l
# !echo 'TXT files: ' | ls -l /content/drive/MyDrive/kaggle_data_split/test/dt/*.txt | grep -v ^l | wc -l

# !echo "train"
# !echo 'All files: ' | ls -l /content/drive/MyDrive/kaggle_data_split/train/dt/*.* | grep -v ^l | wc -l
# !echo 'JPG files: ' | ls -l /content/drive/MyDrive/kaggle_data_split/train/dt/*.jpg | grep -v ^l | wc -l
# !echo 'TXT files: ' | ls -l /content/drive/MyDrive/kaggle_data_split/train/dt/*.txt | grep -v ^l | wc -l

# !echo "val"
# !echo 'All files: ' | ls -l /content/drive/MyDrive/kaggle_data_split/val/dt/*.* | grep -v ^l | wc -l
# !echo 'JPG files: ' | ls -l /content/drive/MyDrive/kaggle_data_split/val/dt/*.jpg | grep -v ^l | wc -l
# !echo 'TXT files: ' | ls -l /content/drive/MyDrive/kaggle_data_split/val/dt/*.txt | grep -v ^l | wc -l
# Out:
# test
# 538
# 269
# 269
# train
# 4290
# 2145
# 2145
# val
# 536
# 268
# 268

# %% [markdown]
# ## Force sync the colab data to Drive
#
# ---

# %% [markdown]
# ### Unsure if helps/works.

# %%
# !sudo add-apt-repository ppa:alessandro-strada/ppa -y
# !sudo apt update && sudo apt install google-drive-ocamlfuse
# !google-drive-ocamlfuse -cc
# Out:
# Repository: 'deb https://ppa.launchpadcontent.net/alessandro-strada/ppa/ubuntu/ jammy main'
# Description:
# Mount Google Drive on Ubuntu (via FUSE)
# More info: https://launchpad.net/~alessandro-strada/+archive/ubuntu/ppa
# Adding repository.
# Adding deb entry to /etc/apt/sources.list.d/alessandro-strada-ubuntu-ppa-jammy.list
# Adding disabled deb-src entry to /etc/apt/sources.list.d/alessandro-strada-ubuntu-ppa-jammy.list
# Adding key to /etc/apt/trusted.gpg.d/alessandro-strada-ubuntu-ppa.gpg with fingerprint 9EA4D6FCA5D37A5D1CA9C09AAD5F235DF639B041
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:4 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# ...

# %% [markdown]
# ### Force sync using flush and unmount. (might take long)

# %%
drive.flush_and_unmount()
